# %%
import pandas as pd

# %%
medal_df = pd.read_html('Olympic Medal Count _ Tokyo 2020 Olympics (Jul 23-Aug 8, 2021).html')
medal_df = medal_df[0]
medal_df.head()
# Out:
#    Rank                    Team/NOC  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0     1    United States of America          39          41          33
# 1     2  People's Republic of China          38          32          18
# 2     3                       Japan          27          14          17
# 3     4               Great Britain          22          21          22
# 4     5                         ROC          20          28          23
#
#    Total  RankbyTotal NOCCode
# 0    113            1     USA
# 1     88            2     CHN
# 2     58            5     JPN
# 3     65            4     GBR
# 4     71            3     ROC

# %%
population_df = pd.read_csv('API_SP.POP.TOTL_DS2_en_csv_v2_2708397.csv')
population_df.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54208.0      55434.0      56234.0      56699.0      57029.0
# 1  130836765.0  134159786.0  137614644.0  141202036.0  144920186.0
# 2    8996967.0    9169406.0    9351442.0    9543200.0    9744772.0
# 3   96396419.0   98407221.0  100506960.0  102691339.0  104953470.0
# 4    5454938.0    5531451.0    5608499.0    5679409.0    5734995.0
#
#           1965  ...         2012         2013         2014         2015  \
# ...

# %% [markdown]
# ### Country Names

# %%
for each_c in medal_df['Team/NOC'].sort_values().unique():
    print (each_c)
# Out:
# Argentina
# Armenia
# Australia
# Austria
# Azerbaijan
# Bahamas
# Bahrain
# Belarus
# Belgium
# Bermuda
# Botswana
# Brazil
# Bulgaria
# Burkina Faso
# Canada
# Chinese Taipei
# Colombia
# Croatia
# Cuba
# Czech Republic
# Côte d'Ivoire
# Denmark
# Dominican Republic
# Ecuador
# Egypt
# Estonia
# Ethiopia
# Fiji
# Finland
# France
# Georgia
# Germany
# Ghana
# Great Britain
# Greece
# Grenada
# Hong Kong, China
# Hungary
# India
# Indonesia
# Ireland
# Islamic Republic of Iran
# Israel
# Italy
# Jamaica
# Japan
# Jordan
# Kazakhstan
# Kenya
# Kosovo
# Kuwait
# Kyrgyzstan
# Latvia
# Lithuania
# Malaysia
# Mexico
# Mongolia
# Morocco
# Namibia
# Netherlands
# New Zealand
# Nigeria
# North Macedonia
# Norway
# People's Republic of China
# Philippines
# Poland
# Portugal
# Puerto Rico
# Qatar
# ROC
# Republic of Korea
# Republic of Moldova
# Romania
# San Marino
# Saudi Arabia
# Serbia
# Slovakia
# Slovenia
# South Africa
# Spain
# Sweden
# Switzerland
# Syrian Arab Republic
# Thailand
# ...

# %%
for c in population_df['Country Name'].sort_values().unique():
    print(c)
# Out:
# Afghanistan
# Africa Eastern and Southern
# Africa Western and Central
# Albania
# Algeria
# American Samoa
# Andorra
# Angola
# Antigua and Barbuda
# Arab World
# Argentina
# Armenia
# Aruba
# Australia
# Austria
# Azerbaijan
# Bahamas, The
# Bahrain
# Bangladesh
# Barbados
# Belarus
# Belgium
# Belize
# Benin
# Bermuda
# Bhutan
# Bolivia
# Bosnia and Herzegovina
# Botswana
# Brazil
# British Virgin Islands
# Brunei Darussalam
# Bulgaria
# Burkina Faso
# Burundi
# Cabo Verde
# Cambodia
# Cameroon
# Canada
# Caribbean small states
# Cayman Islands
# Central African Republic
# Central Europe and the Baltics
# Chad
# Channel Islands
# Chile
# China
# Colombia
# Comoros
# Congo, Dem. Rep.
# Congo, Rep.
# Costa Rica
# Cote d'Ivoire
# Croatia
# Cuba
# Curacao
# Cyprus
# Czech Republic
# Denmark
# Djibouti
# Dominica
# Dominican Republic
# Early-demographic dividend
# East Asia & Pacific
# East Asia & Pacific (IDA & IBRD countries)
# East Asia & Pacific (excluding high income)
# Ecuador
# ...

# %% [markdown]
# Taiwan is not a member of World Bank, hence the population data is get from https://eng.stat.gov.tw/point.asp?index=9 where Taiwan has 23561236 population in 2020

# %% [markdown]
# ### Data Cleaning and Processing

# %% [markdown]
# Get total medals only

# %%
total_medal_df = medal_df.copy()
total_medal_df=total_medal_df.drop(['Rank', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'RankbyTotal', 'NOCCode'], axis=1)
total_medal_df.head()
# Out:
#                      Team/NOC  Total
# 0    United States of America    113
# 1  People's Republic of China     88
# 2                       Japan     58
# 3               Great Britain     65
# 4                         ROC     71

# %% [markdown]
# Rename Olympics countries names with those from World Bank

# %%
total_medal_df['Team/NOC'] = total_medal_df['Team/NOC'].replace(["Bahamas","Chinese Taipei","Côte d'Ivoire","Egypt","Great Britain","Hong Kong, China","Islamic Republic of Iran","Kyrgyzstan","People's Republic of China","ROC","Republic of Korea","Republic of Moldova","Slovakia","United States of America","Venezuela"],["Bahamas, The","Taiwan","Cote d'Ivoire","Egypt, Arab Rep.","United Kingdom","Hong Kong SAR, China","Iran, Islamic Rep.","Kyrgyz Republic","China","Russian Federation","Korea, Rep.","Moldova","Slovak Republic","United States","Venezuela, RB"])
total_medal_df
# Out:
#                 Team/NOC  Total
# 0          United States    113
# 1                  China     88
# 2                  Japan     58
# 3         United Kingdom     65
# 4     Russian Federation     71
# ..                   ...    ...
# 88                 Ghana      1
# 89               Grenada      1
# 90                Kuwait      1
# 91               Moldova      1
# 92  Syrian Arab Republic      1
#
# [93 rows x 2 columns]

# %%
total_medal_df.columns=['Country Name','Total Medals']
total_medal_df
# Out:
#             Country Name  Total Medals
# 0          United States           113
# 1                  China            88
# 2                  Japan            58
# 3         United Kingdom            65
# 4     Russian Federation            71
# ..                   ...           ...
# 88                 Ghana             1
# 89               Grenada             1
# 90                Kuwait             1
# 91               Moldova             1
# 92  Syrian Arab Republic             1
#
# [93 rows x 2 columns]

# %% [markdown]
# Get 2020 Population and Taiwan's into it

# %%
twenty_population_df = population_df.copy()
twenty_population_df = twenty_population_df[['Country Name', '2020']]
twenty_population_df.head()
# Out:
#                   Country Name         2020
# 0                        Aruba     106766.0
# 1  Africa Eastern and Southern  677243299.0
# 2                  Afghanistan   38928341.0
# 3   Africa Western and Central  458803476.0
# 4                       Angola   32866268.0

# %%
new_row = {'Country Name':'Taiwan', '2020':23561236.0}
twenty_population_df = twenty_population_df.append(new_row, ignore_index=True)

# %%
merge_pop_medal_df = pd.merge(total_medal_df, twenty_population_df, on=["Country Name"])
merge_pop_medal_df
# Out:
#             Country Name  Total Medals          2020
# 0          United States           113  3.294841e+08
# 1                  China            88  1.402112e+09
# 2                  Japan            58  1.258360e+08
# 3         United Kingdom            65  6.721529e+07
# 4     Russian Federation            71  1.441041e+08
# ..                   ...           ...           ...
# 88                 Ghana             1  3.107294e+07
# 89               Grenada             1  1.125190e+05
# 90                Kuwait             1  4.270563e+06
# 91               Moldova             1  2.617820e+06
# 92  Syrian Arab Republic             1  1.750066e+07
#
# [93 rows x 3 columns]

# %%
merge_pop_medal_df['Population Per Medal'] = merge_pop_medal_df['2020']/merge_pop_medal_df['Total Medals']
merge_pop_medal_df
# Out:
#             Country Name  Total Medals          2020  Population Per Medal
# 0          United States           113  3.294841e+08          2.915789e+06
# 1                  China            88  1.402112e+09          1.593309e+07
# 2                  Japan            58  1.258360e+08          2.169587e+06
# 3         United Kingdom            65  6.721529e+07          1.034081e+06
# 4     Russian Federation            71  1.441041e+08          2.029635e+06
# ..                   ...           ...           ...                   ...
# 88                 Ghana             1  3.107294e+07          3.107294e+07
# 89               Grenada             1  1.125190e+05          1.125190e+05
# 90                Kuwait             1  4.270563e+06          4.270563e+06
# 91               Moldova             1  2.617820e+06          2.617820e+06
# 92  Syrian Arab Republic             1  1.750066e+07          1.750066e+07
#
# [93 rows x 4 columns]

# %%
merge_pop_medal_df.to_csv('merge_pop_medal_df.csv',index=False)

# %%
check_merge_pop_medal_df = pd.read_csv('merge_pop_medal_df.csv')
check_merge_pop_medal_df
# Out:
#             Country Name  Total Medals          2020  Population Per Medal
# 0          United States           113  3.294841e+08          2.915789e+06
# 1                  China            88  1.402112e+09          1.593309e+07
# 2                  Japan            58  1.258360e+08          2.169587e+06
# 3         United Kingdom            65  6.721529e+07          1.034081e+06
# 4     Russian Federation            71  1.441041e+08          2.029635e+06
# ..                   ...           ...           ...                   ...
# 88                 Ghana             1  3.107294e+07          3.107294e+07
# 89               Grenada             1  1.125190e+05          1.125190e+05
# 90                Kuwait             1  4.270563e+06          4.270563e+06
# 91               Moldova             1  2.617820e+06          2.617820e+06
# 92  Syrian Arab Republic             1  1.750066e+07          1.750066e+07
#
# [93 rows x 4 columns]

# %%
import statistics
print(statistics.mean(check_merge_pop_medal_df['Population Per Medal']))
# Out:
# 9883948.492806168
